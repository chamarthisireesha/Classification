# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('Skyserver_SQL2_27_2018 6_51_39 PM.csv')

# %%
df.head()
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# 0  15.22531  752    301       4    267  3.722360e+18    STAR -0.000009   3306
# 1  16.39150  752    301       4    267  3.638140e+17    STAR -0.000055    323
# 2  16.80125  752    301       4    268  3.232740e+17  GALAXY  0.123111    287
# 3  15.90438  752    301       4    269  3.722370e+18    STAR -0.000111   3306
# 4  16.61326  752    301       4    269  3.722370e+18    STAR  0.000590   3306
#
#      mjd  fiberid
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    0.000000e+00     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %%
df['class']
# Out:
# 0         STAR
# 1         STAR
# 2       GALAXY
# 3         STAR
# 4         STAR
#          ...
# 9995    GALAXY
# 9996    GALAXY
# 9997      STAR
# 9998    GALAXY
# 9999    GALAXY
# Name: class, Length: 10000, dtype: object

# %%
df['class'].value_counts()
# Out:
# GALAXY    4998
# STAR      4152
# QSO        850
# Name: class, dtype: int64

# %% [markdown]
# https://www.kaggle.com/lucidlenn/data-analysis-and-classification-using-xgboost

# %%
sns.countplot(df['class'])

# %%
df.corr()
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %% [markdown]
# https://www.kaggle.com/farazrahman/predicting-star-galaxy-quasar-with-svm

# %% [markdown]
# Brief Details of each observation:
#
# ra (right ascension) and dec (declination) are the coordinates on the sky that correspond to longitude and latitude on Earth. RA measures east and west on the celestial sphere and is like longitude on the Earth. Dec measures north and south on the celestial sphere and is like latitude on the Earth.
#
#     objid = Object Identifier
#     ra = J2000 Right Ascension (r-band)-
#     dec = J2000 Declination (r-band)
#
# Knowing that the color of a star is related to the wavelength of light it gives off, lets you understand the meaning of the SDSS's color filters. Each filter is designed to let in light around a specific wavelength. The filters work by blocking out light at all wavelengths except those around the wavelength they are designed to see.
#
#     u (ultraviolet)= better of DeV/Exp magnitude fit
#     g (green) = better of DeV/Exp magnitude fit
#     r (red) = better of DeV/Exp magnitude fit
#     i (Near infrared) = better of DeV/Exp magnitude fit
#
#     z (Infrared) = better of DeV/Exp magnitude fit
#
#     run = Run Number
#     rereun = Rerun Number
#     camcol = Camera column
#     field = Field number
#     specobjid = Object Identifier
#     class = object class (galaxy, star or quasar object)
#     redshift = Final Redshift
#     plate = plate number
#     mjd = MJD of observation
#     fiberid = fiber ID

# %% [markdown]
# ## Dropping unwanted values

# %% [markdown]
# #### drop run numbers

# %%
df.drop(['run','rerun'],axis=1,inplace=True)

# %%
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z  camcol  field     specobjid   class  redshift  \
# ...

# %% [markdown]
# #### Drop object identifier  values

# %%
df.drop(['objid','specobjid'],axis=1,inplace=True)

# %%
df.drop(['fiberid'],axis=1,inplace=True)

# %%
df
# Out:
#               ra        dec         u         g         r         i         z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9997  131.552562  51.666986  18.75818  17.77784  17.51872  17.43302  17.42048
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
# ...

# %% [markdown]
# https://www.kaggle.com/kredy10/classification-of-interstellar-objects

# %%
df.drop(['camcol','plate','field','mjd'],axis=1,inplace=True)

# %%
df.corr()
# Out:
#                 ra       dec         u         g         r         i  \
# ra        1.000000  0.003596  0.031238  0.043909  0.047103  0.045731
# dec       0.003596  1.000000  0.035279  0.061875  0.063404  0.058292
# u         0.031238  0.035279  1.000000  0.849232  0.692379  0.602630
# g         0.043909  0.061875  0.849232  1.000000  0.958106  0.907419
# r         0.047103  0.063404  0.692379  0.958106  1.000000  0.977672
# i         0.045731  0.058292  0.602630  0.907419  0.977672  1.000000
# z         0.042950  0.056870  0.551483  0.879622  0.969197  0.981507
# redshift  0.030307  0.067021  0.163741  0.407576  0.441080  0.431450
#
#                  z  redshift
# ra        0.042950  0.030307
# dec       0.056870  0.067021
# u         0.551483  0.163741
# g         0.879622  0.407576
# r         0.969197  0.441080
# i         0.981507  0.431450
# z         1.000000  0.424034
# redshift  0.424034  1.000000

# %%
sns.heatmap(df.corr(),annot=True)

# %%
df_S = df[df['class']=='STAR']
df_G = df[df['class']=='GALAXY']
df_Q = df[df['class']=='QSO']

# %%
fig, axes = plt.subplots(nrows=1, ncols=3,figsize=(20, 5))
ax = sns.distplot(df_S['redshift'], bins = 30, ax = axes[0], kde = False)
ax.set_title('Star')
ax = sns.distplot(df_G['redshift'], bins = 30, ax = axes[1], kde = False)
ax.set_title('Galaxy')
ax = sns.distplot(df_Q['redshift'], bins = 30, ax = axes[2], kde = False)
ax = ax.set_title('QSO')

# %%
sns.pairplot(df)

# %% [markdown]
# ## Model

# %%
X = df.drop(['class'],axis=1).values

# %%
y = df['class'].values
y
# Out:
# array(['STAR', 'STAR', 'GALAXY', ..., 'STAR', 'GALAXY', 'GALAXY'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3)

# %%
from sklearn.svm import SVC

# %%
model = SVC(kernel='linear')

model.fit(X_train,y_train)
model.predict(X_test)
# Out:
# array(['STAR', 'GALAXY', 'GALAXY', ..., 'GALAXY', 'GALAXY', 'STAR'],
#       dtype=object)

# %%
from sklearn import svm,linear_model,tree,neighbors,naive_bayes,ensemble,discriminant_analysis,gaussian_process
from xgboost import XGBClassifier 
from sklearn import metrics

# %%
model_func = [
    
    # Ensemble Methods
    ensemble.AdaBoostClassifier(),
    ensemble.BaggingClassifier(),
    ensemble.ExtraTreesClassifier(),
    ensemble.GradientBoostingClassifier(),
    ensemble.RandomForestClassifier(),
    
    
    ## Gaussian Procedure
    gaussian_process.GaussianProcessClassifier(),
    
     #GLM
    linear_model.LogisticRegressionCV(),
    linear_model.PassiveAggressiveClassifier(),
    linear_model.RidgeClassifierCV(),
    linear_model.SGDClassifier(),
    linear_model.Perceptron(),
    
    #Navies Bayes
    naive_bayes.BernoulliNB(),
    naive_bayes.GaussianNB(),
    
    #Nearest Neighbor
    neighbors.KNeighborsClassifier(),
    
    #SVM
    svm.SVC(probability=True),
    svm.SVC(kernel='rbf'),
    svm.SVC(kernel='linear'),
    svm.LinearSVC(),
    
    #Trees    
    tree.DecisionTreeClassifier(),
    tree.ExtraTreeClassifier(),
    
    #Discriminant Analysis
    discriminant_analysis.LinearDiscriminantAnalysis(),
    discriminant_analysis.QuadraticDiscriminantAnalysis(),

    
    #xgboost: http://xgboost.readthedocs.io/en/latest/model.html
    XGBClassifier()    
    ]

# %%
model_cols = ['Model_name','Accuracy']

comparision_df = pd.DataFrame(columns = model_cols)

# %%
row_index = 0
for i in model_func:
    Model_name = i.__class__.__name__
    comparision_df.loc[row_index,'Model_name'] = Model_name
    
    #fiting the model
    i.fit(X_train, y_train)

    #prediction
    y_pred = i.predict(X_test)

    #Accuracy
    comparision_df.loc[row_index,'Accuracy'] = (metrics.accuracy_score(y_pred,y_test))
        
    row_index+=1
    
comparision_df.sort_values(by = ['Accuracy'], ascending = False, inplace = True)
# Out:
# /home/sireesha/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/sireesha/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
comparision_df
# Out:
#                        Model_name  Accuracy
# 22                  XGBClassifier  0.992333
# 1               BaggingClassifier  0.990333
# 3      GradientBoostingClassifier  0.989333
# 4          RandomForestClassifier  0.988333
# 21  QuadraticDiscriminantAnalysis  0.986667
# 18         DecisionTreeClassifier  0.983667
# 2            ExtraTreesClassifier  0.981667
# 12                     GaussianNB     0.977
# 16                            SVC  0.967667
# 6            LogisticRegressionCV     0.963
# 19            ExtraTreeClassifier     0.939
# 17                      LinearSVC  0.924333
# 20     LinearDiscriminantAnalysis  0.914333
# 8               RidgeClassifierCV  0.894333
# 0              AdaBoostClassifier     0.876
# 5       GaussianProcessClassifier  0.783333
# 13           KNeighborsClassifier     0.755
# 9                   SGDClassifier  0.734333
# 11                    BernoulliNB  0.686667
# 7     PassiveAggressiveClassifier     0.667
# ...

# %% [markdown]
# ## Standard scalar

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model_cols = ['Model_name','Accuracy']

comparision_df_SC = pd.DataFrame(columns = model_cols)

# %%
row_index = 0
for i in model_func:
    Model_name = i.__class__.__name__
    comparision_df_SC.loc[row_index,'Model_name'] = Model_name
    
    #fiting the model
    i.fit(X_train, y_train)

    #prediction
    y_pred = i.predict(X_test)

    #Accuracy
    comparision_df_SC.loc[row_index,'Accuracy'] = (metrics.accuracy_score(y_pred,y_test))
        
    row_index+=1
    
comparision_df_SC.sort_values(by = ['Accuracy'], ascending = False, inplace = True)
# Out:
# /home/sireesha/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/sireesha/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
comparision_df_SC
# Out:
#                        Model_name  Accuracy
# 22                  XGBClassifier  0.992333
# 6            LogisticRegressionCV  0.991667
# 1               BaggingClassifier  0.991333
# 4          RandomForestClassifier  0.989333
# 3      GradientBoostingClassifier  0.988667
# 21  QuadraticDiscriminantAnalysis  0.986667
# 16                            SVC  0.982667
# 18         DecisionTreeClassifier  0.981667
# 2            ExtraTreesClassifier  0.980667
# 12                     GaussianNB  0.980333
# 10                     Perceptron      0.97
# 17                      LinearSVC  0.965667
# 9                   SGDClassifier  0.964333
# 14                            SVC  0.959667
# 15                            SVC  0.959667
# 5       GaussianProcessClassifier  0.918333
# 20     LinearDiscriminantAnalysis  0.914333
# 19            ExtraTreeClassifier  0.911333
# 8               RidgeClassifierCV     0.894
# 13           KNeighborsClassifier  0.893667
# ...

# %% [markdown]
# ## Cross validation
#
# https://towardsdatascience.com/train-test-split-and-cross-validation-in-python-80b61beca4b6
#
#
# https://towardsdatascience.com/why-and-how-to-cross-validate-a-model-d6424b45261f

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
import numpy as np

# %%
X_CV = sc.fit_transform(X)

# %%
cv = KFold(n_splits=5,shuffle=True)

# %% [markdown]
# ## Only accuracy
#
# https://stackoverflow.com/questions/47257952/how-to-get-average-score-of-k-fold-cross-validation-with-sklearn
#
# https://datascience.stackexchange.com/questions/28988/cross-validation-for-different-metrics-sklearn

# %%
model_cols = ['Model_name','Accuracy']

comparision_df_CVScore = pd.DataFrame(columns = model_cols)

# %%
row_index = 0
for mod in model_func:
    Model_name = mod.__class__.__name__
    comparision_df_CVScore.loc[row_index,'Model_name'] = Model_name
    
    scores = cross_val_score(mod, X_CV, y,scoring='accuracy', cv=cv)
    

    #Accuracy
    comparision_df_CVScore.loc[row_index,'Accuracy'] = np.mean(scores)
    
        
    row_index+=1
    
comparision_df_CVScore.sort_values(by = ['Accuracy'], ascending = False, inplace = True)
# Out:
# /home/sireesha/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /home/sireesha/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
comparision_df_CVScore
# Out:
#                        Model_name Accuracy
# 1               BaggingClassifier   0.9913
# 22                  XGBClassifier   0.9911
# 6            LogisticRegressionCV   0.9911
# 3      GradientBoostingClassifier   0.9901
# 4          RandomForestClassifier   0.9891
# 18         DecisionTreeClassifier   0.9867
# 21  QuadraticDiscriminantAnalysis   0.9857
# 2            ExtraTreesClassifier   0.9848
# 16                            SVC   0.9832
# 12                     GaussianNB   0.9796
# 17                      LinearSVC   0.9695
# 7     PassiveAggressiveClassifier   0.9666
# 9                   SGDClassifier    0.965
# 14                            SVC   0.9626
# 15                            SVC   0.9622
# 10                     Perceptron   0.9476
# 5       GaussianProcessClassifier   0.9307
# 19            ExtraTreeClassifier   0.9221
# 20     LinearDiscriminantAnalysis   0.9207
# 13           KNeighborsClassifier   0.9055
# 8               RidgeClassifierCV   0.9046
# ...
